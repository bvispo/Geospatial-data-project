# %%
from pymongo import MongoClient
import requests
import json
from dotenv import load_dotenv
import os
import pandas as pd

# %% [markdown]
# # Función de coordenadas

# %%
def geocode(direccion):
    """
    Esta función saca las coordenadas de la dirección que le pases
    """
    data = requests.get(f"https://geocode.xyz/{direccion}?json=1").json()
    try:
        return {"type": "Point", "coordinates": [data["latt"], data["longt"]]}
    except:
        return data

# %%
load_dotenv()
# Out:
# True

# %%
client_id = os.getenv("tok1")
client_secret = os.getenv("tok2")

# %% [markdown]
# # MADRID

# %%
madrid = geocode("Puerta del Sol, Madrid") #coordenadas de Madrid

# %%
madrid
# Out:
# {'type': 'Point', 'coordinates': ['40.41703', '-3.70343']}

# %%
#url = "https://favqs.com/api/session"
url_query = 'https://api.foursquare.com/v2/venues/search'
url_recomendados = 'https://api.foursquare.com/v2/venues/explore'

# %%
def funcion(string):
    parametros = {
    "client_id": client_id,
    "client_secret": client_secret,
    "v": "20180323",
    "ll": f"{madrid['coordinates'][0]}, {madrid['coordinates'][1]}",
    "query": f"{string}" #aquí pongo lo que quiero buscar en Madrid.
}
    resp = requests.get(url_query, params = parametros).json()
    data = resp["response"]["venues"]
    df = pd.DataFrame(data)
    
    return df

# %%
funcion("Veterinarios")
# Out:
#                           id  \
# 0   4dd127ff22718eed7a79158d
# 1   4e182641c65b6bfb590ba5b8
# 2   4d3958efcc48224b7969324f
# 3   5319a2c7498ee85781f0b05e
# 4   4edcabfe722e1da304eb43d0
# 5   4eea2c63b8f7eaddf79bcf66
# 6   55d85bee498ebd939b048cfe
# 7   4ef1b42c29c2e7e6d196fa8e
# 8   4ef0f1ef6da156f4ac4073eb
# 9   54bfe1b5498e4cb53120c3e8
# 10  4ef1b3707ee5e58929b96c96
# 11  57a30b0a498e83a8cb44289e
# 12  526240eb498eaec5316f39e0
# 13  52b2d26c11d207bb61e1ecfc
# 14  565ed8e2498e70d23fb1889c
# 15  50ca01b1e4b0cc6a8b5b1527
# 16  5069ce2fe4b064a76e0ad0f3
# 17  4c02e09bf56c2d7f6f1b1c66
# 18  531463ac11d2358d5bd89f84
# 19  4fd1bcbee4b0341af6b6550b
# 20  4e5f5bc41f6e3022a7310bc6
# 21  4dce6d54ae603b786d2e5193
# 22  4ed6a1d39911b345bd2ec473
# 23  5e6986bd43333e000864bd4e
# 24  530daa8d498e140e02a77bbe
# 25  583ef433febfbd79f8930be7
# 26  4bc4bad874a9a5931b43d6f6
# 27  51c86ad1498e024da67e4b8f
# 28  4c28af60ed0ac9b67b8f60aa
# 29  4f8aed14e4b029818b940a9d
#
#                                                  name contact  \
# 0           Colegio Oficial De Veterinarios De Madrid      {}
# 1   Consejo General De Colegios Veterinarios De Es...      {}
# 2                                  Vetpa Veterinarios      {}
# 3         VetSalud Servicios Veterinarios a Domicilio      {}
# 4                                  Draco veterinarios      {}
# 5            Veterinario A Domicilio SAD VETERINARIOS      {}
# 6                               Veterinario Sur Batán      {}
# 7            VETERINARIO A DOMICILIO SaD Veterinarios      {}
# 8            Veterinario A Domicilio SAD VETERINARIOS      {}
# 9                                  Ancora Veterinaros      {}
# 10           VETERINARIO A DOMICILIO SaD Veterinarios      {}
# 11                       Centro Veterinario Salamanca      {}
# 12                              Centauro Veterinarios      {}
# 13                               Go! Vet Veterinarios      {}
# 14                     Centro Veterinario Salvatierra      {}
# 15                             Centro Veterinario Sur      {}
# 16                                 veterinarios layos      {}
# 17                              Veterinario San Roque      {}
# 18                     Centro veterinario Sanchinarro      {}
# 19                     Centro Veterinario San Nicasio      {}
# 20                        Clínica Veterinaria El Nido      {}
# 21                   Hospital veterinario san agustin      {}
# 22                                  Jara Veterinarios      {}
# 23                          Grupo Cívica Veterinarios      {}
# 24                          Grupo Cívica Veterinarios      {}
# 25                    Centro Veterinario Salud Animal      {}
# 26                    Centro Veterinario Sierra Norte      {}
# 27                    Centro Veterinario Santa Teresa      {}
# 28              Hospital Veterinario Sierra De Madrid      {}
# 29                       Centro Veterinario San Antón      {}
#
#                                              location  \
# 0   {'address': 'Calle del Maestro Ripoll, 8', 'la...
# 1   {'address': 'Villanueva 11', 'lat': 40.422585,...
# 2   {'address': 'C/ de Benito Gutiérrez 26', 'lat'...
# 3   {'address': 'Olaya Alvarez', 'lat': 40.4, 'lng...
# 4   {'address': 'Canillas 20', 'lat': 40.436244904...
# 5   {'address': 'www.servicioveterinarioadomicilio...
# 6   {'address': 'Cebreros 101', 'lat': 40.40290832...
# 7   {'address': 'Www.servicioveterinarioadomiilio....
# 8   {'address': 'www.servicioveterinarioadomicilio...
# 9   {'address': 'Calle General Lacy, 22', 'lat': 4...
# 10  {'address': 'Www.servicioveterinarioadomicilio...
# 11  {'lat': 40.426094, 'lng': -3.6776075, 'labeled...
# 12  {'lat': 40.35288111237679, 'lng': -3.817371589...
# 13  {'address': 'Av. Bellas Vistas, 1', 'crossStre...
# 14  {'address': 'Calle los Yébenes 89', 'lat': 40....
# 15  {'address': 'Avenida Pablo Neruda 69', 'lat': ...
# 16  {'lat': 40.493906884568275, 'lng': -3.37756879...
# 17  {'lat': 40.23606, 'lng': -3.770285, 'labeledLa...
# 18  {'lat': 40.49525200701478, 'lng': -3.654212069...
# 19  {'address': 'Calle RIO URBION, 2, Local 3', 'l...
# 20  {'address': 'C/ Alcorcón 19', 'crossStreet': '...
# 21  {'lat': 40.60422, 'lng': -3.581831, 'labeledLa...
# 22  {'address': 'Calle Redondillo, 3', 'lat': 40.6...
# 23  {'address': 'Avenida de Madrid, 335, URB CALIP...
# 24  {'lat': 40.2510871887207, 'lng': -4.0618348121...
# 25  {'lat': 40.213091, 'lng': -3.851387, 'labeledL...
# 26  {'lat': 40.662308, 'lng': -3.777732, 'labeledL...
# 27  {'address': 'Calle Gimialcón, 3, Port. 4  5;Ba...
# 28  {'lat': 40.675305, 'lng': -3.62232, 'labeledLa...
# 29  {'address': 'Carretera de Valdemorillo, 22, 28...
#
#                                            categories  verified  \
# 0   [{'id': '4bf58dd8d48988d1a8941735', 'name': 'G...     False
# 1   [{'id': '4bf58dd8d48988d1a8941735', 'name': 'G...     False
# 2                                                  []     False
# 3   [{'id': '5032897c91d4c4b30a586d69', 'name': 'P...     False
# 4   [{'id': '4bf58dd8d48988d100951735', 'name': 'P...     False
# 5   [{'id': '4d954af4a243a5684765b473', 'name': 'V...     False
# 6   [{'id': '4d954af4a243a5684765b473', 'name': 'V...     False
# 7   [{'id': '4d954af4a243a5684765b473', 'name': 'V...     False
# 8   [{'id': '4d954af4a243a5684765b473', 'name': 'V...     False
# 9   [{'id': '4d954af4a243a5684765b473', 'name': 'V...     False
# 10  [{'id': '4d954af4a243a5684765b473', 'name': 'V...     False
# 11  [{'id': '4d954af4a243a5684765b473', 'name': 'V...     False
# 12  [{'id': '4d954af4a243a5684765b473', 'name': 'V...     False
# 13  [{'id': '5032897c91d4c4b30a586d69', 'name': 'P...     False
# 14  [{'id': '4d954af4a243a5684765b473', 'name': 'V...     False
# 15  [{'id': '4d954af4a243a5684765b473', 'name': 'V...     False
# 16  [{'id': '4e52d2d203646f7c19daa8ae', 'name': 'A...     False
# 17  [{'id': '4bf58dd8d48988d104941735', 'name': 'M...     False
# 18  [{'id': '4d954af4a243a5684765b473', 'name': 'V...     False
# 19  [{'id': '4d954af4a243a5684765b473', 'name': 'V...     False
# 20                                                 []      True
# 21  [{'id': '4d954af4a243a5684765b473', 'name': 'V...     False
# 22  [{'id': '4d954af4a243a5684765b473', 'name': 'V...     False
# 23  [{'id': '4d954af4a243a5684765b473', 'name': 'V...     False
# 24  [{'id': '5032897c91d4c4b30a586d69', 'name': 'P...     False
# 25  [{'id': '4e52d2d203646f7c19daa8ae', 'name': 'A...     False
# 26  [{'id': '4d954af4a243a5684765b473', 'name': 'V...     False
# 27                                                 []      True
# 28  [{'id': '4bf58dd8d48988d104941735', 'name': 'M...     False
# 29  [{'id': '4d954af4a243a5684765b473', 'name': 'V...     False
#
#                                                 stats  \
# 0   {'tipCount': 0, 'usersCount': 0, 'checkinsCoun...
# 1   {'tipCount': 0, 'usersCount': 0, 'checkinsCoun...
# 2   {'tipCount': 0, 'usersCount': 0, 'checkinsCoun...
# 3   {'tipCount': 0, 'usersCount': 0, 'checkinsCoun...
# 4   {'tipCount': 0, 'usersCount': 0, 'checkinsCoun...
# 5   {'tipCount': 0, 'usersCount': 0, 'checkinsCoun...
# 6   {'tipCount': 0, 'usersCount': 0, 'checkinsCoun...
# 7   {'tipCount': 0, 'usersCount': 0, 'checkinsCoun...
# 8   {'tipCount': 0, 'usersCount': 0, 'checkinsCoun...
# 9   {'tipCount': 0, 'usersCount': 0, 'checkinsCoun...
# 10  {'tipCount': 0, 'usersCount': 0, 'checkinsCoun...
# 11  {'tipCount': 0, 'usersCount': 0, 'checkinsCoun...
# 12  {'tipCount': 0, 'usersCount': 0, 'checkinsCoun...
# 13  {'tipCount': 0, 'usersCount': 0, 'checkinsCoun...
# 14  {'tipCount': 0, 'usersCount': 0, 'checkinsCoun...
# 15  {'tipCount': 0, 'usersCount': 0, 'checkinsCoun...
# 16  {'tipCount': 0, 'usersCount': 0, 'checkinsCoun...
# 17  {'tipCount': 0, 'usersCount': 0, 'checkinsCoun...
# 18  {'tipCount': 0, 'usersCount': 0, 'checkinsCoun...
# 19  {'tipCount': 0, 'usersCount': 0, 'checkinsCoun...
# 20  {'tipCount': 0, 'usersCount': 0, 'checkinsCoun...
# 21  {'tipCount': 0, 'usersCount': 0, 'checkinsCoun...
# 22  {'tipCount': 0, 'usersCount': 0, 'checkinsCoun...
# 23  {'tipCount': 0, 'usersCount': 0, 'checkinsCoun...
# 24  {'tipCount': 0, 'usersCount': 0, 'checkinsCoun...
# 25  {'tipCount': 0, 'usersCount': 0, 'checkinsCoun...
# 26  {'tipCount': 0, 'usersCount': 0, 'checkinsCoun...
# 27  {'tipCount': 0, 'usersCount': 0, 'checkinsCoun...
# 28  {'tipCount': 0, 'usersCount': 0, 'checkinsCoun...
# 29  {'tipCount': 0, 'usersCount': 0, 'checkinsCoun...
#
#                                              beenHere  \
# 0   {'count': 0, 'lastCheckinExpiredAt': 0, 'marke...
# 1   {'count': 0, 'lastCheckinExpiredAt': 0, 'marke...
# 2   {'count': 0, 'lastCheckinExpiredAt': 0, 'marke...
# 3   {'count': 0, 'lastCheckinExpiredAt': 0, 'marke...
# 4   {'count': 0, 'lastCheckinExpiredAt': 0, 'marke...
# 5   {'count': 0, 'lastCheckinExpiredAt': 0, 'marke...
# 6   {'count': 0, 'lastCheckinExpiredAt': 0, 'marke...
# 7   {'count': 0, 'lastCheckinExpiredAt': 0, 'marke...
# 8   {'count': 0, 'lastCheckinExpiredAt': 0, 'marke...
# 9   {'count': 0, 'lastCheckinExpiredAt': 0, 'marke...
# 10  {'count': 0, 'lastCheckinExpiredAt': 0, 'marke...
# 11  {'count': 0, 'lastCheckinExpiredAt': 0, 'marke...
# 12  {'count': 0, 'lastCheckinExpiredAt': 0, 'marke...
# 13  {'count': 0, 'lastCheckinExpiredAt': 0, 'marke...
# 14  {'count': 0, 'lastCheckinExpiredAt': 0, 'marke...
# 15  {'count': 0, 'lastCheckinExpiredAt': 0, 'marke...
# 16  {'count': 0, 'lastCheckinExpiredAt': 0, 'marke...
# 17  {'count': 0, 'lastCheckinExpiredAt': 0, 'marke...
# 18  {'count': 0, 'lastCheckinExpiredAt': 0, 'marke...
# 19  {'count': 0, 'lastCheckinExpiredAt': 0, 'marke...
# 20  {'count': 0, 'lastCheckinExpiredAt': 0, 'marke...
# 21  {'count': 0, 'lastCheckinExpiredAt': 0, 'marke...
# 22  {'count': 0, 'lastCheckinExpiredAt': 0, 'marke...
# 23  {'count': 0, 'lastCheckinExpiredAt': 0, 'marke...
# 24  {'count': 0, 'lastCheckinExpiredAt': 0, 'marke...
# 25  {'count': 0, 'lastCheckinExpiredAt': 0, 'marke...
# 26  {'count': 0, 'lastCheckinExpiredAt': 0, 'marke...
# 27  {'count': 0, 'lastCheckinExpiredAt': 0, 'marke...
# 28  {'count': 0, 'lastCheckinExpiredAt': 0, 'marke...
# 29  {'count': 0, 'lastCheckinExpiredAt': 0, 'marke...
#
#                                               hereNow    referralId  \
# 0   {'count': 0, 'summary': 'Nobody here', 'groups...  v-1636808970
# 1   {'count': 0, 'summary': 'Nobody here', 'groups...  v-1636808970
# 2   {'count': 0, 'summary': 'Nobody here', 'groups...  v-1636808970
# 3   {'count': 0, 'summary': 'Nobody here', 'groups...  v-1636808970
# 4   {'count': 0, 'summary': 'Nobody here', 'groups...  v-1636808970
# 5   {'count': 0, 'summary': 'Nobody here', 'groups...  v-1636808970
# 6   {'count': 0, 'summary': 'Nobody here', 'groups...  v-1636808970
# 7   {'count': 0, 'summary': 'Nobody here', 'groups...  v-1636808970
# 8   {'count': 0, 'summary': 'Nobody here', 'groups...  v-1636808970
# 9   {'count': 0, 'summary': 'Nobody here', 'groups...  v-1636808970
# 10  {'count': 0, 'summary': 'Nobody here', 'groups...  v-1636808970
# 11  {'count': 0, 'summary': 'Nobody here', 'groups...  v-1636808970
# 12  {'count': 0, 'summary': 'Nobody here', 'groups...  v-1636808970
# 13  {'count': 0, 'summary': 'Nobody here', 'groups...  v-1636808970
# 14  {'count': 0, 'summary': 'Nobody here', 'groups...  v-1636808970
# 15  {'count': 0, 'summary': 'Nobody here', 'groups...  v-1636808970
# 16  {'count': 0, 'summary': 'Nobody here', 'groups...  v-1636808970
# 17  {'count': 0, 'summary': 'Nobody here', 'groups...  v-1636808970
# 18  {'count': 0, 'summary': 'Nobody here', 'groups...  v-1636808970
# 19  {'count': 0, 'summary': 'Nobody here', 'groups...  v-1636808970
# 20  {'count': 0, 'summary': 'Nobody here', 'groups...  v-1636808970
# 21  {'count': 0, 'summary': 'Nobody here', 'groups...  v-1636808970
# 22  {'count': 0, 'summary': 'Nobody here', 'groups...  v-1636808970
# 23  {'count': 0, 'summary': 'Nobody here', 'groups...  v-1636808970
# 24  {'count': 0, 'summary': 'Nobody here', 'groups...  v-1636808970
# 25  {'count': 0, 'summary': 'Nobody here', 'groups...  v-1636808970
# 26  {'count': 0, 'summary': 'Nobody here', 'groups...  v-1636808970
# 27  {'count': 0, 'summary': 'Nobody here', 'groups...  v-1636808970
# 28  {'count': 0, 'summary': 'Nobody here', 'groups...  v-1636808970
# 29  {'count': 0, 'summary': 'Nobody here', 'groups...  v-1636808970
#
#    venueChains  hasPerk            venuePage
# 0           []    False                  NaN
# 1           []    False                  NaN
# 2           []    False                  NaN
# 3           []    False                  NaN
# 4           []    False                  NaN
# 5           []    False                  NaN
# 6           []    False                  NaN
# 7           []    False                  NaN
# 8           []    False                  NaN
# 9           []    False                  NaN
# 10          []    False                  NaN
# 11          []    False                  NaN
# 12          []    False                  NaN
# 13          []    False                  NaN
# 14          []    False                  NaN
# 15          []    False                  NaN
# 16          []    False                  NaN
# 17          []    False                  NaN
# 18          []    False                  NaN
# 19          []    False                  NaN
# 20          []    False                  NaN
# 21          []    False                  NaN
# 22          []    False                  NaN
# 23          []    False                  NaN
# 24          []    False                  NaN
# 25          []    False                  NaN
# 26          []    False                  NaN
# 27          []    False  {'id': '141552983'}
# 28          []    False                  NaN
# 29          []    False                  NaN

# %%
parametros = {
    "client_id": client_id,
    "client_secret": client_secret,
    "v": "20180323",
    "ll": f"{madrid['coordinates'][0]}, {madrid['coordinates'][1]}",
    "query": "Starbucks" #aquí pongo lo que quiero buscar en las coordenadas de Madrid.
}

# %%
resp = requests.get(url_query, params = parametros).json()

# %%
type(resp)
# Out:
# dict

# %%
resp["response"].keys()
# Out:
# dict_keys(['venues'])

# %%
import pyjsonviewer

# %%
import json
with open('data.json', 'w') as f:
    json.dump(resp, f)

# %%
#pyjsonviewer.view_data(json_file="data.json")

# %%
#pyjsonviewer.view_data(json_data=resp)

# %%
data = resp["response"]["venues"]

# %%
starbucks = pd.DataFrame(data)

# %%
starbucks.sample()
# Out:
#                           id       name contact  \
# 16  598986e1f5e9d717167f751f  Starbucks      {}
#
#                                              location  \
# 16  {'address': 'C. Velázquez, 32', 'lat': 40.4249...
#
#                                            categories  verified  \
# 16  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...      True
#
#                                                 stats  \
# 16  {'tipCount': 0, 'usersCount': 0, 'checkinsCoun...
#
#                                              beenHere  \
# 16  {'count': 0, 'lastCheckinExpiredAt': 0, 'marke...
#
#                                               hereNow    referralId  \
# 16  {'count': 0, 'summary': 'Nobody here', 'groups...  v-1636808680
#
#    venueChains  hasPerk
# 16          []    False

# %%
starbucks.loc[1]["location"]
# Out:
# {'address': 'C. Arenal, 14',
#  'lat': 40.41719516711848,
#  'lng': -3.706118548830636,
#  'labeledLatLngs': [{'label': 'display',
#    'lat': 40.41719516711848,
#    'lng': -3.706118548830636}],
#  'distance': 228,
#  'postalCode': '28013',
#  'cc': 'ES',
#  'city': 'Madrid',
#  'state': 'Madrid',
#  'country': 'España',
#  'formattedAddress': ['C. Arenal, 14', '28013 Madrid Madrid', 'España']}

# %%
from functools import reduce
import operator

# %%
def getFromDict(diccionario,mapa):
    return reduce(operator.getitem,mapa,diccionario)

# %%
map_ = ["location", "lat"]

# %%
getFromDict(resp["response"]["venues"][0], map_)
# Out:
# 40.417539

# %%
resp["response"]["venues"][0]["location"]["address"]
# Out:
# 'Calle de la Montera 8'

# %%
def type_point(lista):
    return {"type":"Point", "coordinates": lista}

# %%
todo = {"nombre": ["name"], "dirección": ["location", "address"], "latitud": ["location", "lat"], "longitud": ["location", "lng"]}

# %%
starbucks_ = resp["response"]["venues"] #Librerías es el json grande donde tengo toda la info de cada librería

# %%
def extraetodo(json):
    todo = {"nombre": ["name"], "latitud": ["location", "lat"], "longitud": ["location", "lng"]} 
    total = []
    for elemento in json:
        libre = {key: getFromDict(elemento, value) for key,value in todo.items()}
        libre["location"] = type_point([libre["latitud"], libre["longitud"]])
        total.append(libre)
    return total

# %%
lovemosclaro = extraetodo(starbucks_)

# %%
data_ = pd.DataFrame(lovemosclaro)

# %%
data_.head()
# Out:
#       nombre    latitud  longitud  \
# 0  Starbucks  40.417539 -3.702775
# 1  Starbucks  40.417195 -3.706119
# 2  Starbucks  40.420140 -3.702886
# 3  Starbucks  40.418038 -3.699372
# 4  Starbucks  40.417489 -3.704665
#
#                                             location
# 0  {'type': 'Point', 'coordinates': [40.417539, -...
# 1  {'type': 'Point', 'coordinates': [40.417195167...
# 2  {'type': 'Point', 'coordinates': [40.420140393...
# 3  {'type': 'Point', 'coordinates': [40.418038185...
# 4  {'type': 'Point', 'coordinates': [40.417489421...

# %%
starbuscks_madrid = data_.copy()

# %%
import json
with open ("starbucks_.json","w") as f: # creamos un archivo vacío en el que vamos a escribir
    json.dump(lovemosclaro,f) # cargamos nuestra lista de diccionarios en ese archivo

# %%
import geopandas as gpd

# %%
gdf = gpd.GeoDataFrame(starbuscks_madrid, geometry=gpd.points_from_xy(starbuscks_madrid.longitud, starbuscks_madrid.latitud))

# %%
from cartoframes.viz import Map, Layer, popup_element

# %%
Map(Layer(gdf, "color:purple", popup_hover=[popup_element("nombre", "Starbucks de Madrid")]))
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
#   <script type=&quot;module&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship/airship.esm.js&quot;></script>
#   <script src=&quot;https://libs.cartocdn.com/airship-bridge/v2.3/asbridge.min.js&quot;></script>
#   <link href=&quot;https://libs.cartocdn.com/airship-style/v2.3/airship.min.css&quot; rel=&quot;stylesheet&quot;>
#   <link href=&quot;https://libs.cartocdn.com/airship-icons/v2.3/icons.css&quot; rel=&quot;stylesheet&quot;>
#
#   <link href=&quot;https://fonts.googleapis.com/css?family=Roboto&quot; rel=&quot;stylesheet&quot; type=&quot;text/css&quot;>
#
#   <!-- External libraries -->
#
#   <!-- pako -->
#   <script src=&quot;https://libs.cartocdn.com/cartoframes/dependencies/pako_inflate.min.js&quot;></script>
#
#   <!-- html2canvas -->
#
#
#
#   <style>
#   body {
#     margin: 0;
#     padding: 0;
#   }
#
#   aside.as-sidebar {
#     min-width: 300px;
#   }
#
#   .map-image {
#     display: none;
#     max-width: 100%;
#     height: auto;
#   }
#
#   as-layer-selector-slot .as-layer-selector-slot--wrapper .as-caption { // FIXME
#     font-size: 14px;
#     line-height: 14px;
#   }
# </style>
#   <style>
#   .map {
#     position: absolute;
#     height: 100%;
#     width: 100%;
#   }
#
#   .map-info {
#     position: absolute;
#     bottom: 0;
#     padding: 0 5px;
#     background-color: rgba(255, 255, 255, 0.5);
#     margin: 0;
#     color: rgba(0, 0, 0, 0.75);
#     font-size: 12px;
#     width: auto;
#     height: 18px;
#     font-family: 'Open Sans';
#   }
#
#   .map-footer {
#     background: #F2F6F9;
#     font-family: Roboto;
#     font-size: 12px;
#     line-height: 24px;
#     color: #162945;
#     text-align: center;
#     z-index: 2;
#   }
#
#   .map-footer a {
#     text-decoration: none;
#   }
#
#   .map-footer a:hover {
#     text-decoration: underline;
#   }
# </style>
#     <style>
#     #error-container {
#       position: absolute;
#       width: 100%;
#       height: 100%;
#       background-color: white;
#       visibility: hidden;
#       padding: 1em;
#       font-family: &quot;Courier New&quot;, Courier, monospace;
#       margin: 0 auto;
#       font-size: 14px;
#       overflow: auto;
#       z-index: 1000;
#       color: black;
#     }
#
#     .error-section {
#       padding: 1em;
#       border-radius: 5px;
#       background-color: #fee;
#     }
#
#     #error-container #error-highlight {
#       font-weight: bold;
#       color: inherit;
#     }
#
#     #error-container #error-type {
#       color: #008000;
#     }
#
#     #error-container #error-name {
#       color: #ba2121;
#     }
#
#     #error-container #error-content {
#       margin-top: 0.4em;
#     }
#
#     .error-details {
#       margin-top: 1em;
#     }
#
#     #error-stacktrace {
#       list-style: none;
#     }
# </style>
#   <style>
#     .popup-content {
#       display: flex;
#       flex-direction: column;
#       padding: 8px;
#     }
#
#     .popup-name {
#       font-size: 12px;
#       font-weight: 400;
#       line-height: 20px;
#       margin-bottom: 4px;
#     }
#
#     .popup-value {
#       font-size: 16px;
#       font-weight: 600;
#       line-height: 20px;
#     }
#
#     .popup-value:not(:last-of-type) {
#       margin-bottom: 16px;
#     }
# </style>
#   <style>
#   as-widget-header .as-widget-header__header {
#     margin-bottom: 8px;
#     overflow-wrap: break-word;
#   }
#
#   as-widget-header .as-widget-header__subheader {
#     margin-bottom: 12px;
#   }
#
#   as-category-widget {
#     max-height: 250px;
#   }
# </style>
# </head>
#
# <body class=&quot;as-app-body as-app&quot;>
#   <img id=&quot;map-image&quot; class=&quot;map-image&quot; alt='Static map image' />
#   <as-responsive-content id=&quot;main-container&quot;>
#
#     <main class=&quot;as-main&quot;>
#       <div class=&quot;as-map-area&quot;>
#         <div id=&quot;map&quot; class=&quot;map&quot;></div>
#
#
#       </div> <!-- as-map-area -->
#     </main> <!-- as-main -->
#   </as-responsive-content>
#
#
#
#   <div id=&quot;error-container&quot; class=&quot;error&quot;>
#   <section class=&quot;error-section&quot;>
#     <span class=&quot;errors&quot; id=&quot;error-name&quot;></span>:
#     <section id=&quot;error-content&quot;>
#       <span class=&quot;errors&quot; id=&quot;error-type&quot;></span>
#       <span class=&quot;errors&quot; id=&quot;error-message&quot;></span>
#     </section>
#   </section>
#
#   <details class=&quot;error-details&quot;>
#     <summary>StackTrace</summary>
#     <ul id=&quot;error-stacktrace&quot;></ul>
#   </details>
# </div>
# </body>
#
# <script>
#   var init = (function () {
#   'use strict';
#
#   const BASEMAPS = {
#     DarkMatter: carto.basemaps.darkmatter,
#     Voyager: carto.basemaps.voyager,
#     Positron: carto.basemaps.positron
#   };
#
#   const attributionControl = new mapboxgl.AttributionControl({
#     compact: false
#   });
#
#   const FIT_BOUNDS_SETTINGS = { animate: false, padding: 50, maxZoom: 16 };
#
#   /** From https://github.com/errwischt/stacktrace-parser/blob/master/src/stack-trace-parser.js */
#
#   /**
#    * This parses the different stack traces and puts them into one format
#    * This borrows heavily from TraceKit (https://github.com/csnover/TraceKit)
#    */
#
#   const UNKNOWN_FUNCTION = '<unknown>';
#   const chromeRe = /^\s*at (.*?) ?\(((?:file|https?|blob|chrome-extension|native|eval|webpack|<anonymous>|\/).*?)(?::(\d+))?(?::(\d+))?\)?\s*$/i;
#   const chromeEvalRe = /\((\S*)(?::(\d+))(?::(\d+))\)/;
#   const winjsRe = /^\s*at (?:((?:\[object object\])?.+) )?\(?((?:file|ms-appx|https?|webpack|blob):.*?):(\d+)(?::(\d+))?\)?\s*$/i;
#   const geckoRe = /^\s*(.*?)(?:\((.*?)\))?(?:^|@)((?:file|https?|blob|chrome|webpack|resource|\[native).*?|[^@]*bundle)(?::(\d+))?(?::(\d+))?\s*$/i;
#   const geckoEvalRe = /(\S+) line (\d+)(?: > eval line \d+)* > eval/i;
#
#   function parse(stackString) {
#     const lines = stackString.split('\n');
#
#     return lines.reduce((stack, line) => {
#       const parseResult =
#         parseChrome(line) ||
#         parseWinjs(line) ||
#         parseGecko(line);
#
#       if (parseResult) {
#         stack.push(parseResult);
#       }
#
#       return stack;
#     }, []);
#   }
#
#   function parseChrome(line) {
#     const parts = chromeRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     const isNative = parts[2] && parts[2].indexOf('native') === 0; // start of line
#     const isEval = parts[2] && parts[2].indexOf('eval') === 0; // start of line
#
#     const submatch = chromeEvalRe.exec(parts[2]);
#     if (isEval && submatch != null) {
#       // throw out eval line/column and use top-most line/column number
#       parts[2] = submatch[1]; // url
#       parts[3] = submatch[2]; // line
#       parts[4] = submatch[3]; // column
#     }
#
#     return {
#       file: !isNative ? parts[2] : null,
#       methodName: parts[1] || UNKNOWN_FUNCTION,
#       arguments: isNative ? [parts[2]] : [],
#       lineNumber: parts[3] ? +parts[3] : null,
#       column: parts[4] ? +parts[4] : null,
#     };
#   }
#
#   function parseWinjs(line) {
#     const parts = winjsRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     return {
#       file: parts[2],
#       methodName: parts[1] || UNKNOWN_FUNCTION,
#       arguments: [],
#       lineNumber: +parts[3],
#       column: parts[4] ? +parts[4] : null,
#     };
#   }
#
#   function parseGecko(line) {
#     const parts = geckoRe.exec(line);
#
#     if (!parts) {
#       return null;
#     }
#
#     const isEval = parts[3]
