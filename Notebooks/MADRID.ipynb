# %%
from pymongo import MongoClient
import requests
from dotenv import load_dotenv
import os
import pandas as pd
import geopandas as gpd
from cartoframes.viz import Map, Layer, popup_element
from functools import reduce
import operator
import json

# %%
def geocode(direccion):
    """
    Esta función saca las coordenadas de la dirección que le pases
    """
    data = requests.get(f"https://geocode.xyz/{direccion}?json=1").json()
    try:
        return {"type": "Point", "coordinates": [data["latt"], data["longt"]]}
    except:
        return data

# %%
load_dotenv()
client_id = os.getenv("tok1")
client_secret = os.getenv("tok2")

# %%
madrid = geocode("Paseo de la Castellana, Madrid") #coordenadas de Madrid

# %%
madrid
# Out:
# {'type': 'Point', 'coordinates': ['40.46879', '-3.68915']}

# %%
def getFromDict(diccionario,mapa):
    return reduce(operator.getitem,mapa,diccionario)

# %%
def extraetodo(json):
    todo = {"nombre": ["name"], "latitud": ["location", "lat"], "longitud": ["location", "lng"]} 
    total = []
    for elemento in json:
        place = {key: getFromDict(elemento, value) for key,value in todo.items()}
        place["location"] = type_point([place["latitud"], place["longitud"]])
        total.append(place)
    return total

# %%
def type_point(lista):
    return {"type":"Point", "coordinates": lista}

# %%
def funcion(string):
    url_query = 'https://api.foursquare.com/v2/venues/search'
    url_recomendados = 'https://api.foursquare.com/v2/venues/explore'
    parametros = {
    "client_id": client_id,
    "client_secret": client_secret,
    "v": "20180323",
    "ll": f"{madrid['coordinates'][0]}, {madrid['coordinates'][1]}", #aquí pongo la ciudad que quiero
    "query": f"{string}" #aquí pongo lo que quiero buscar en la ciudad.
}
    resp = requests.get(url_query, params = parametros).json()
    data = resp["response"]["venues"]
    df = pd.DataFrame(data)
    map_ = ["location", "lat"]
    getFromDict(resp["response"]["venues"][0], map_)
    resp["response"]["venues"][0]["location"]["address"]
    loquebusco = resp["response"]["venues"]
    lovemosclaro = extraetodo(loquebusco)
    data_final = pd.DataFrame(lovemosclaro)
    #download data as json
    with open ("madrd.json","w") as f: # creamos un archivo vacío en el que vamos a escribir
        json.dump(lovemosclaro,f) # cargamos nuestra lista de diccionarios en ese archivo
    
    return data_final

# %% [markdown]
# # STARBUCKS

# %%
funcion("Starbucks")
# Out:
#                    nombre    latitud  longitud  \
# 0               Starbucks  40.447489 -3.693093
# 1               Starbucks  40.447729 -3.695175
# 2               Starbucks  40.455046 -3.693885
# 3               Starbucks  40.432968 -3.683220
# 4               Starbucks  40.479636 -3.707357
# 5               Starbucks  40.433564 -3.686829
# 6               Starbucks  40.429069 -3.715079
# 7               Starbucks  40.417195 -3.706119
# 8               Starbucks  40.420140 -3.702886
# 9               Starbucks  40.459101 -3.685668
# 10              Starbucks  40.421752 -3.708378
# 11              Starbucks  40.497687 -3.660368
# 12              Starbucks  40.418038 -3.699372
# 13              Starbucks  40.425760 -3.691782
# 14              Starbucks  40.424975 -3.684107
# 15              Starbucks  40.417539 -3.702775
# 16              Starbucks  40.426067 -3.675617
# 17              Starbucks  40.423320 -3.710883
# 18              Starbucks  40.415733 -3.708718
# ...

# %% [markdown]
# #### WE VISUALIZE IT

# %%
def visualizar ():
    starbuscks_madrid = funcion("Starbucks")
    gdf = gpd.GeoDataFrame(starbuscks_madrid, geometry=gpd.points_from_xy(starbuscks_madrid.longitud, starbuscks_madrid.latitud))
    return Map(Layer(gdf, "color:purple", popup_hover=[popup_element("nombre", "Starbucks de Madrid")]))
visualizar()
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
# ...

# %% [markdown]
# # Train Station

# %%
funcion("Estación de Madrid") #quiero sólo la 0 y la 1
# Out:
#                                                nombre    latitud  longitud  \
# 0                        Estación de Madrid-Chamartín  40.472806 -3.682393
# 1                 Estación de Madrid-Puerta de Atocha  40.406403 -3.689550
# 2                   Estación de Madrid-Chamartín Adif  40.472092 -3.682341
# 3            Estación de Madrid-Puerta de Atocha Adif  40.405027 -3.688313
# 4        Andén 15 Estación de Madrid-Puerta de Atocha  40.404915 -3.690174
# 5           Vía 2 Estación de Madrid-Puerta de Atocha  40.405605 -3.689473
# 6           Vía 3 Estación de Madrid-Puerta de Atocha  40.404507 -3.687450
# 7     Andén 3 AVE Estación de Madrid-Puerta de Atocha  40.404065 -3.687371
# 8              Estación de Cercanías de Madrid-Atocha  40.405497 -3.688216
# 9     Anden 5 AVE Estación de Madrid-Puerta de Atocha  40.405386 -3.689466
# 10   Andén Vía 12 Estación de Madrid-Puerta de Atocha  40.404857 -3.689550
# ...

# %% [markdown]
# ### WE VISUALIZE IT

# %%
def visualizar ():
    stations_madrid = funcion("Estación de Madrid")
    gdf = gpd.GeoDataFrame(stations_madrid, geometry=gpd.points_from_xy(stations_madrid.longitud, stations_madrid.latitud))
    return Map(Layer(gdf, "color:purple", popup_hover=[popup_element("nombre", "Estaciones de Madrid")]))
visualizar()
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
# ...

# %% [markdown]
# # DAY CARE

# %%
funcion("Guardería")
# Out:
#                                                nombre    latitud  longitud  \
# 0   Guardería Hospital Clínico Universitario San C...  40.439612 -3.717949
# 1                                Guarderia Kinderland  40.456024 -3.693350
# 2                                  Guarderia El Pinar  40.481258 -3.671693
# 3                             Guarderia Ciudad Jardin  40.456826 -3.670749
# 4         Happyschool Guardería y Escuelas infantiles  40.478921 -3.696866
# 5                                     Guardería Pecas  40.437671 -3.808231
# 6                         Guardería My School Risitas  40.445792 -3.686320
# 7                                   Guardería Nervión  40.446249 -3.683680
# 8                                 Guarderia los nanos  40.448457 -3.673745
# 9                                   guarderia mirasol  40.485262 -3.712586
# 10                      Guarderia les Ptits Bilingues  40.460661 -3.657267
# ...

# %% [markdown]
# ### WE VISUALIZE IT

# %%
def visualizar ():
    guarderia_madrid = funcion("Guardería")
    gdf = gpd.GeoDataFrame(guarderia_madrid, geometry=gpd.points_from_xy(guarderia_madrid.longitud, guarderia_madrid.latitud))
    return Map(Layer(gdf, "color:purple", popup_hover=[popup_element("nombre", "Guarderías de Madrid")]))
visualizar()
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
# ...

# %% [markdown]
# # BAR

# %%
funcion("bar")
# Out:
#                                nombre    latitud  longitud  \
# 0               Dala's Cervecería Bar  40.469888 -3.686491
# 1                        Bar Gago III  40.465466 -3.691736
# 2                 Eurostars Lobby Bar  40.476684 -3.687386
# 3          Klimt Gin Club Premium Bar  40.461318 -3.691867
# 4                         Bar Machico  40.469166 -3.686506
# 5                          Bar Alloco  40.459265 -3.673379
# 6   Bar Cerveceria Soccer- Sports Bar  40.476970 -3.669049
# 7                  Bar "La mina" Café  40.469347 -3.687093
# 8                   Bar Los Torreznos  40.441387 -3.697533
# 9                        Bar J. Simón  40.469461 -3.686426
# 10                         Bar Delfín  40.449049 -3.695312
# 11                         Tapas  Bar  40.451044 -3.691557
# 12                           Bar Poli  40.470697 -3.692106
# 13                       Bar Valencia  40.470544 -3.692164
# 14                     Bar Plaza Cafe  40.470060 -3.685954
# ...

# %%
def visualizar ():
    guarderia_madrid = funcion("Bar")
    gdf = gpd.GeoDataFrame(guarderia_madrid, geometry=gpd.points_from_xy(guarderia_madrid.longitud, guarderia_madrid.latitud))
    return Map(Layer(gdf, "color:purple", popup_hover=[popup_element("nombre", "Guarderías de Madrid")]))
visualizar()
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
# ...
