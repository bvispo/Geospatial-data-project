# %%
from pymongo import MongoClient
import requests
from dotenv import load_dotenv
import os
import pandas as pd
import geopandas as gpd
from cartoframes.viz import Map, Layer, popup_element
from functools import reduce
import operator
import json

# %%
def geocode(direccion):
    """
    Esta función saca las coordenadas de la dirección que le pases
    """
    data = requests.get(f"https://geocode.xyz/{direccion}?json=1").json()
    try:
        return {"type": "Point", "coordinates": [data["latt"], data["longt"]]}
    except:
        return data

# %%
load_dotenv()
client_id = os.getenv("tok1")
client_secret = os.getenv("tok2")

# %%
london = geocode("St Paul´s Cathedral, London") #coordenadas de Madrid

# %%
london
# Out:
# {'type': 'Point', 'coordinates': ['51.51421', '-0.05688']}

# %%
def getFromDict(diccionario,mapa):
    return reduce(operator.getitem,mapa,diccionario)

# %%
def extraetodo(json):
    todo = {"nombre": ["name"], "latitud": ["location", "lat"], "longitud": ["location", "lng"]} 
    total = []
    for elemento in json:
        place = {key: getFromDict(elemento, value) for key,value in todo.items()}
        place["location"] = type_point([place["latitud"], place["longitud"]])
        total.append(place)
    return total

# %%
def type_point(lista):
    return {"type":"Point", "coordinates": lista}

# %%
def funcion(string):
    url_query = 'https://api.foursquare.com/v2/venues/search'
    url_recomendados = 'https://api.foursquare.com/v2/venues/explore'
    parametros = {
    "client_id": client_id,
    "client_secret": client_secret,
    "v": "20180323",
    "ll": f"{london['coordinates'][0]}, {london['coordinates'][1]}", #aquí pongo la ciudad que quiero
    "query": f"{string}" #aquí pongo lo que quiero buscar en la ciudad.
}
    resp = requests.get(url_query, params = parametros).json()
    data = resp["response"]["venues"]
    df = pd.DataFrame(data)
    map_ = ["location", "lat"]
    getFromDict(resp["response"]["venues"][0], map_)
    resp["response"]["venues"][0]["location"]["address"]
    loquebusco = resp["response"]["venues"]
    lovemosclaro = extraetodo(loquebusco)
    data_final = pd.DataFrame(lovemosclaro)
    #download data as json
    with open ("london.json","w") as f: # creamos un archivo vacío en el que vamos a escribir
        json.dump(lovemosclaro,f) # cargamos nuestra lista de diccionarios en ese archivo
    
    return data_final

# %% [markdown]
# # STARBUCKS

# %%
funcion("Starbucks")
# Out:
#                           nombre    latitud  longitud  \
# 0                      Starbucks  51.517003 -0.068061
# 1                      Starbucks  51.508436 -0.079160
# 2                      Starbucks  51.511556 -0.075125
# 3                      Starbucks  51.506741 -0.074081
# 4                      Starbucks  51.510831 -0.085434
# 5                      Starbucks  51.525053 -0.035272
# 6                      Starbucks  51.507450 -0.122863
# 7                      Starbucks  51.505487 -0.085133
# 8                      Starbucks  51.514579 -0.096092
# 9                      Starbucks  51.518920 -0.168813
# 10                     Starbucks  51.513391 -0.082912
# 11                     Starbucks  51.527250 -0.055608
# 12                     Starbucks  51.512707 -0.088153
# 13                     Starbucks  51.494898 -0.046504
# 14                     Starbucks  51.500533 -0.162604
# 15                     Starbucks  51.513868 -0.117669
# ...

# %% [markdown]
# #### WE VISUALIZE IT

# %%
def visualizar ():
    starbuscks_london = funcion("Starbucks")
    gdf = gpd.GeoDataFrame(starbuscks_london, geometry=gpd.points_from_xy(starbuscks_london.longitud, starbuscks_london.latitud))
    return Map(Layer(gdf, "color:purple", popup_hover=[popup_element("nombre", "London Starbucks")]))
visualizar()
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
# ...

# %% [markdown]
# # Train Station

# %%
funcion("Train Station")
# Out:
#                                                nombre    latitud  longitud  \
# 0   London Liverpool Street Railway Station (LST) ...  51.517913 -0.081676
# 1                                   The Train Station  51.446263 -0.163138
# 2   London Euston Railway Station (EUS) (London Eu...  51.528134 -0.133426
# 3               Bermondsey London Underground Station  51.497800 -0.063743
# 4   London King's Cross Railway Station (KGX) (Lon...  51.531516 -0.124163
# 5   London Waterloo Railway Station (WAT) (London ...  51.503212 -0.112864
# 6                     Limehouse Railway Station (LHS)  51.512538 -0.039729
# 7   London St Pancras International Railway Statio...  51.531982 -0.126086
# 8       London Fenchurch Street Railway Station (FST)  51.511299 -0.076809
# 9                 H20 Bus Stop Hounslow Train Station  51.464030 -0.362763
# 10  London Bridge Railway Station (LBG) (London Br...  51.504391 -0.084614
# ...

# %% [markdown]
# #### WE VISUALIZE IT

# %%
def visualizar ():
    stations_london = funcion("Train Station")
    gdf = gpd.GeoDataFrame(stations_london, geometry=gpd.points_from_xy(stations_london.longitud, stations_london.latitud))
    return Map(Layer(gdf, "color:purple", popup_hover=[popup_element("nombre", "London Train Stations")]))
visualizar()
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
# ...

# %% [markdown]
# # DAY CARE

# %%
funcion("nursery")
# Out:
#                                                nombre    latitud  longitud  \
# 0   Bright Horizons West Hampstead Day Nursery and...  51.542960 -0.191080
# 1                               New Birth Day Nursery  51.516457 -0.045873
# 2                          Alice Model Nursery School  51.521197 -0.046554
# 3                              DreamMaker Day Nursery  51.509388 -0.071150
# 4                                    Low Hall Nursery  51.522667 -0.046913
# 5                                Academic Day Nursery  51.556030 -0.089608
# 6                    Weavers Fields Community Nursery  51.524844 -0.062172
# 7                                Tiddley Tots Nursery  51.561890 -0.078650
# 8   Bright Horizons Spitalfields Day Nursery and P...  51.520314 -0.074974
# 9                           Monkey Puzzle Day Nursery  51.552354 -0.101710
# 10  Bright Horizons Peckham Rye Day Nursery and Pr...  51.461035 -0.058626
# ...

# %% [markdown]
# #### WE VISUALIZE IT

# %%
def visualizar ():
    london_daycare = funcion("nursery")
    gdf = gpd.GeoDataFrame(london_daycare, geometry=gpd.points_from_xy(london_daycare.longitud, london_daycare.latitud))
    return Map(Layer(gdf, "color:purple", popup_hover=[popup_element("nombre", "London Day Care")]))
visualizar()
# Out:
# <iframe
#   frameborder="0"
#   style="
#     border: 1px solid #cfcfcf;
#     width: 100%;
#     height: 632px;
#     "
#   srcDoc="
#   <!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
#   <title>None</title>
#   <meta name=&quot;description&quot; content=&quot;None&quot;>
#   <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
#   <meta charset=&quot;UTF-8&quot;>
#   <!-- Include CARTO VL JS -->
#   <script src=&quot;https://libs.cartocdn.com/carto-vl/v1.4/carto-vl.min.js&quot;></script>
#   <!-- Include Mapbox GL JS -->
#   <script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.js&quot;></script>
#   <!-- Include Mapbox GL CSS -->
#   <link href=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.0.0/mapbox-gl.css&quot; rel=&quot;stylesheet&quot; />
#
#   <!-- Include Airship -->
#   <script nomodule=&quot;&quot; src=&quot;https://libs.cartocdn.com/airship-components/v2.3/airship.js&quot;></script>
# ...
